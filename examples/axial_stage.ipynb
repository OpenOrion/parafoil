# %% [markdown]
# # Axial Turbine Stage
# ![Axial Turbine](../assets/axial_turb.png)

# %%
import numpy as np
from parafoil import Airfoil, AirfoilPassage, MeshParameters, AxialTurboPassage
from ezmesh import visualize_mesh

rotor_airfoil = Airfoil(
    inlet_angle=np.radians(40.0),
    outlet_angle=np.radians(-20.0),
    stagger_angle=np.radians(-30.0),
    upper_thick_dist=[0.002 , 0.008 , 0.008 , 0.002 , 0.0004],
    lower_thick_dist=[0.002 , 0.008 , 0.008 , 0.002 , 0.0004],
    leading_prop=0.5,
    trailing_prop=0.5,
    chord_length=0.0577,
)

stator_airfoil = Airfoil(
    inlet_angle=np.radians(-40.0),
    outlet_angle=np.radians(30.0),
    stagger_angle=np.radians(30.0),
    upper_thick_dist=[0.002 , 0.008 , 0.008 , 0.002 , 0.0004],
    lower_thick_dist=[0.002 , 0.008 , 0.008 , 0.002 , 0.0004],
    leading_prop=0.5,
    trailing_prop=0.5,
    chord_length=0.0577,
)

axial_turbo_passage = AxialTurboPassage(
    inflow_passage=AirfoilPassage(
        airfoil=rotor_airfoil,
        spacing=1.0 * rotor_airfoil.chord_length,
        leading_edge_gap=0.01,
        trailing_edge_gap=0.01,
        num_blades=1,
        mesh_params=MeshParameters(
            airfoil_label="wall1",
            bottom_label="periodic1",
            top_label="periodic2",
            inlet_label="inflow",
            outlet_label="outmix",
        )
    ),
    outflow_passage=AirfoilPassage(
        airfoil=stator_airfoil,
        spacing=1.0 * stator_airfoil.chord_length,
        leading_edge_gap=0.01,
        trailing_edge_gap=0.01,
        num_blades=1,
        mesh_params=MeshParameters(
            airfoil_label="wall2",
            bottom_label="periodic3",
            top_label="periodic4",
            inlet_label="inmix",
            outlet_label="outflow",
        )
    )
)

visualize_mesh(axial_turbo_passage.get_mesh())
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Nurb)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Nurb)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Line)
# Info    : [ 10%] Meshing curve 10 (Line)
# Info    : [ 10%] Meshing curve 11 (Line)
# Info    : [ 20%] Meshing curve 12 (Line)
# Info    : [ 20%] Meshing curve 13 (Line)
# Info    : [ 20%] Meshing curve 14 (Line)
# Info    : [ 20%] Meshing curve 15 (Line)
# Info    : [ 20%] Meshing curve 16 (Line)
# Info    : [ 20%] Meshing curve 17 (Line)
# Info    : [ 20%] Meshing curve 18 (Line)
# Info    : [ 20%] Meshing curve 19 (Line)
# Info    : [ 20%] Meshing curve 20 (Line)
# Info    : [ 20%] Meshing curve 21 (Line)
# Info    : [ 30%] Meshing curve 22 (Line)
# Info    : [ 30%] Meshing curve 23 (Line)
# Info    : [ 30%] Meshing curve 24 (Line)
# Info    : [ 30%] Meshing curve 25 (Line)
# Info    : [ 30%] Meshing curve 26 (Line)
# Info    : [ 30%] Meshing curve 27 (Line)
# Info    : [ 30%] Meshing curve 28 (Line)
# Info    : [ 30%] Meshing curve 29 (Line)
# Info    : [ 30%] Meshing curve 30 (Line)
# Info    : [ 30%] Meshing curve 31 (Line)
# Info    : [ 40%] Meshing curve 32 (Line)
# Info    : [ 40%] Meshing curve 33 (Line)
# Info    : [ 40%] Meshing curve 34 (Line)
# Info    : [ 40%] Meshing curve 35 (Line)
# Info    : [ 40%] Meshing curve 36 (Line)
# Info    : [ 40%] Meshing curve 37 (Line)
# Info    : [ 40%] Meshing curve 38 (Line)
# Info    : [ 40%] Meshing curve 39 (Line)
# Info    : [ 40%] Meshing curve 40 (Line)
# Info    : [ 40%] Meshing curve 41 (Line)
# Info    : [ 50%] Meshing curve 42 (Line)
# Info    : [ 50%] Meshing curve 43 (Line)
# Info    : [ 50%] Meshing curve 44 (Line)
# Info    : [ 50%] Meshing curve 45 (Line)
# Info    : [ 50%] Meshing curve 46 (Line)
# Info    : [ 50%] Meshing curve 47 (Line)
# Info    : [ 50%] Meshing curve 48 (Line)
# Info    : [ 50%] Meshing curve 49 (Line)
# Info    : [ 50%] Meshing curve 50 (Line)
# Info    : [ 50%] Meshing curve 51 (Line)
# Info    : [ 50%] Meshing curve 52 (Line)
# Info    : [ 60%] Meshing curve 53 (Line)
# Info    : [ 60%] Meshing curve 54 (Line)
# Info    : [ 60%] Meshing curve 55 (Line)
# Info    : [ 60%] Meshing curve 56 (Line)
# Info    : [ 60%] Meshing curve 57 (Line)
# Info    : [ 60%] Meshing curve 58 (Line)
# Info    : [ 60%] Meshing curve 59 (Line)
# Info    : [ 60%] Meshing curve 60 (Line)
# Info    : [ 60%] Meshing curve 61 (Line)
# Info    : [ 60%] Meshing curve 62 (Line)
# Info    : [ 70%] Meshing curve 63 (Line)
# Info    : [ 70%] Meshing curve 64 (Line)
# Info    : [ 70%] Meshing curve 65 (Line)
# Info    : [ 70%] Meshing curve 66 (Line)
# Info    : [ 70%] Meshing curve 67 (Line)
# Info    : [ 70%] Meshing curve 68 (Line)
# Info    : [ 70%] Meshing curve 69 (Line)
# Info    : [ 70%] Meshing curve 70 (Line)
# Info    : [ 70%] Meshing curve 71 (Line)
# Info    : [ 70%] Meshing curve 72 (Line)
# Info    : [ 80%] Meshing curve 73 (Line)
# Info    : [ 80%] Meshing curve 74 (Line)
# Info    : [ 80%] Meshing curve 75 (Line)
# Info    : [ 80%] Meshing curve 76 (Line)
# Info    : [ 80%] Meshing curve 77 (Line)
# Info    : [ 80%] Meshing curve 78 (Line)
# Info    : [ 80%] Meshing curve 79 (Line)
# Info    : [ 80%] Meshing curve 80 (Line)
# Info    : [ 80%] Meshing curve 81 (Line)
# Info    : [ 80%] Meshing curve 82 (Line)
# Info    : [ 90%] Meshing curve 83 (Line)
# Info    : [ 90%] Meshing curve 84 (Line)
# Info    : [ 90%] Meshing curve 85 (Line)
# Info    : [ 90%] Meshing curve 86 (Line)
# Info    : [ 90%] Meshing curve 87 (Line)
# Info    : [ 90%] Meshing curve 88 (Line)
# Info    : [ 90%] Meshing curve 89 (Line)
# Info    : [ 90%] Meshing curve 90 (Line)
# Info    : [ 90%] Meshing curve 91 (Line)
# Info    : [ 90%] Meshing curve 92 (Line)
# Info    : [100%] Meshing curve 93 (Line)
# Info    : [100%] Meshing curve 94 (Line)
# Info    : [100%] Meshing curve 95 (Line)
# Info    : [100%] Meshing curve 96 (Line)
# Info    : [100%] Meshing curve 97 (Line)
# Info    : [100%] Meshing curve 98 (Line)
# Info    : [100%] Meshing curve 99 (Line)
# Info    : [100%] Meshing curve 100 (Line)
# Info    : [100%] Meshing curve 101 (Line)
# Info    : [100%] Meshing curve 102 (Line)
# Info    : Done meshing 1D (Wall 0.0421562s, CPU 0.036727s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0714016s, CPU 0.061567s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 2.7061e-05s, CPU 2.1e-05s)
# Info    : 2642 nodes 4276 elements
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Nurb)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Nurb)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Line)
# Info    : [ 10%] Meshing curve 10 (Line)
# Info    : [ 10%] Meshing curve 11 (Line)
# Info    : [ 20%] Meshing curve 12 (Line)
# Info    : [ 20%] Meshing curve 13 (Line)
# Info    : [ 20%] Meshing curve 14 (Line)
# Info    : [ 20%] Meshing curve 15 (Line)
# Info    : [ 20%] Meshing curve 16 (Line)
# Info    : [ 20%] Meshing curve 17 (Line)
# Info    : [ 20%] Meshing curve 18 (Line)
# Info    : [ 20%] Meshing curve 19 (Line)
# Info    : [ 20%] Meshing curve 20 (Line)
# Info    : [ 20%] Meshing curve 21 (Line)
# Info    : [ 30%] Meshing curve 22 (Line)
# Info    : [ 30%] Meshing curve 23 (Line)
# Info    : [ 30%] Meshing curve 24 (Line)
# Info    : [ 30%] Meshing curve 25 (Line)
# Info    : [ 30%] Meshing curve 26 (Line)
# Info    : [ 30%] Meshing curve 27 (Line)
# Info    : [ 30%] Meshing curve 28 (Line)
# Info    : [ 30%] Meshing curve 29 (Line)
# Info    : [ 30%] Meshing curve 30 (Line)
# Info    : [ 30%] Meshing curve 31 (Line)
# Info    : [ 40%] Meshing curve 32 (Line)
# Info    : [ 40%] Meshing curve 33 (Line)
# Info    : [ 40%] Meshing curve 34 (Line)
# Info    : [ 40%] Meshing curve 35 (Line)
# Info    : [ 40%] Meshing curve 36 (Line)
# Info    : [ 40%] Meshing curve 37 (Line)
# Info    : [ 40%] Meshing curve 38 (Line)
# Info    : [ 40%] Meshing curve 39 (Line)
# Info    : [ 40%] Meshing curve 40 (Line)
# Info    : [ 40%] Meshing curve 41 (Line)
# Info    : [ 50%] Meshing curve 42 (Line)
# Info    : [ 50%] Meshing curve 43 (Line)
# Info    : [ 50%] Meshing curve 44 (Line)
# Info    : [ 50%] Meshing curve 45 (Line)
# Info    : [ 50%] Meshing curve 46 (Line)
# Info    : [ 50%] Meshing curve 47 (Line)
# Info    : [ 50%] Meshing curve 48 (Line)
# Info    : [ 50%] Meshing curve 49 (Line)
# Info    : [ 50%] Meshing curve 50 (Line)
# Info    : [ 50%] Meshing curve 51 (Line)
# Info    : [ 50%] Meshing curve 52 (Line)
# Info    : [ 60%] Meshing curve 53 (Line)
# Info    : [ 60%] Meshing curve 54 (Line)
# Info    : [ 60%] Meshing curve 55 (Line)
# Info    : [ 60%] Meshing curve 56 (Line)
# Info    : [ 60%] Meshing curve 57 (Line)
# Info    : [ 60%] Meshing curve 58 (Line)
# Info    : [ 60%] Meshing curve 59 (Line)
# Info    : [ 60%] Meshing curve 60 (Line)
# Info    : [ 60%] Meshing curve 61 (Line)
# Info    : [ 60%] Meshing curve 62 (Line)
# Info    : [ 70%] Meshing curve 63 (Line)
# Info    : [ 70%] Meshing curve 64 (Line)
# Info    : [ 70%] Meshing curve 65 (Line)
# Info    : [ 70%] Meshing curve 66 (Line)
# Info    : [ 70%] Meshing curve 67 (Line)
# Info    : [ 70%] Meshing curve 68 (Line)
# Info    : [ 70%] Meshing curve 69 (Line)
# Info    : [ 70%] Meshing curve 70 (Line)
# Info    : [ 70%] Meshing curve 71 (Line)
# Info    : [ 70%] Meshing curve 72 (Line)
# Info    : [ 80%] Meshing curve 73 (Line)
# Info    : [ 80%] Meshing curve 74 (Line)
# Info    : [ 80%] Meshing curve 75 (Line)
# Info    : [ 80%] Meshing curve 76 (Line)
# Info    : [ 80%] Meshing curve 77 (Line)
# Info    : [ 80%] Meshing curve 78 (Line)
# Info    : [ 80%] Meshing curve 79 (Line)
# Info    : [ 80%] Meshing curve 80 (Line)
# Info    : [ 80%] Meshing curve 81 (Line)
# Info    : [ 80%] Meshing curve 82 (Line)
# Info    : [ 90%] Meshing curve 83 (Line)
# Info    : [ 90%] Meshing curve 84 (Line)
# Info    : [ 90%] Meshing curve 85 (Line)
# Info    : [ 90%] Meshing curve 86 (Line)
# Info    : [ 90%] Meshing curve 87 (Line)
# Info    : [ 90%] Meshing curve 88 (Line)
# Info    : [ 90%] Meshing curve 89 (Line)
# Info    : [ 90%] Meshing curve 90 (Line)
# Info    : [ 90%] Meshing curve 91 (Line)
# Info    : [ 90%] Meshing curve 92 (Line)
# Info    : [100%] Meshing curve 93 (Line)
# Info    : [100%] Meshing curve 94 (Line)
# Info    : [100%] Meshing curve 95 (Line)
# Info    : [100%] Meshing curve 96 (Line)
# Info    : [100%] Meshing curve 97 (Line)
# Info    : [100%] Meshing curve 98 (Line)
# Info    : [100%] Meshing curve 99 (Line)
# Info    : [100%] Meshing curve 100 (Line)
# Info    : [100%] Meshing curve 101 (Line)
# Info    : [100%] Meshing curve 102 (Line)
# Info    : Done meshing 1D (Wall 0.0311235s, CPU 0.026379s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0552092s, CPU 0.054873s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 1.3452e-05s, CPU 1.6e-05s)
# Info    : 2680 nodes 4338 elements
# /usr/local/lib/python3.10/site-packages/pythreejs/traits.py:257: UserWarning: 64-bit data types not supported for WebGL data, casting to 32-bit.
#   warnings.warn('64-bit data types not supported for WebGL '
# HTML(value='Coords: ()')
# Renderer(camera=PerspectiveCamera(aspect=1.3333333333333333, far=100000.0, near=0.001, position=(0.0, 0.0, 1.0…
# <div style="float: left; padding-right: 50px"><h2>Markers</h2><table><tr><td style="background-color: rgb(254,3,3)" width="20"></td><td>periodic1</td></tr><tr><td style="background-color: rgb(252,159,19)" width="20"></td><td>outmix</td></tr><tr><td style="background-color: rgb(206,247,40)" width="20"></td><td>inflow</td></tr><tr><td style="background-color: rgb(91,250,51)" width="20"></td><td>periodic2</td></tr><tr><td style="background-color: rgb(9,252,106)" width="20"></td><td>wall1</td></tr><tr><td style="background-color: rgb(32,249,249)" width="20"></td><td>periodic3</td></tr><tr><td style="background-color: rgb(50,131,254)" width="20"></td><td>periodic4</td></tr><tr><td style="background-color: rgb(84,43,247)" width="20"></td><td>inmix</td></tr><tr><td style="background-color: rgb(201,15,248)" width="20"></td><td>outflow</td></tr><tr><td style="background-color: rgb(254,21,161)" width="20"></td><td>wall2</td></tr></table></div><div style="float: left; padding-right: 50px"><h2>Zones</h2><table><tr><td style="background-color: rgb(127,127,127)" width="20"></td><td>Zone 0</td></tr><tr><td style="background-color: rgb(191,191,191)" width="20"></td><td>Zone 1</td></tr></table></div>

# %%
from paraflow import run_simulation, get_flasher
import pysu2

flasher = get_flasher("air", "gas")
inlet_total_state = flasher.flash(P=101000, T=288, mach_number=0.396501)
outlet_static_state = flasher.flash(P=130000, T=273, mach_number=0.396501)

sim_result = run_simulation(axial_turbo_passage, inlet_total_state, outlet_static_state, "/workspaces/parafoil/simulation", "1", pysu2.CMultizoneDriver) # type: ignore
print(sim_result)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Nurb)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Nurb)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Line)
# Info    : [ 10%] Meshing curve 10 (Line)
# Info    : [ 10%] Meshing curve 11 (Line)
# Info    : [ 20%] Meshing curve 12 (Line)
# Info    : [ 20%] Meshing curve 13 (Line)
# Info    : [ 20%] Meshing curve 14 (Line)
# Info    : [ 20%] Meshing curve 15 (Line)
# Info    : [ 20%] Meshing curve 16 (Line)
# Info    : [ 20%] Meshing curve 17 (Line)
# Info    : [ 20%] Meshing curve 18 (Line)
# Info    : [ 20%] Meshing curve 19 (Line)
# Info    : [ 20%] Meshing curve 20 (Line)
# Info    : [ 20%] Meshing curve 21 (Line)
# Info    : [ 30%] Meshing curve 22 (Line)
# Info    : [ 30%] Meshing curve 23 (Line)
# Info    : [ 30%] Meshing curve 24 (Line)
# Info    : [ 30%] Meshing curve 25 (Line)
# Info    : [ 30%] Meshing curve 26 (Line)
# Info    : [ 30%] Meshing curve 27 (Line)
# Info    : [ 30%] Meshing curve 28 (Line)
# Info    : [ 30%] Meshing curve 29 (Line)
# Info    : [ 30%] Meshing curve 30 (Line)
# Info    : [ 30%] Meshing curve 31 (Line)
# Info    : [ 40%] Meshing curve 32 (Line)
# Info    : [ 40%] Meshing curve 33 (Line)
# Info    : [ 40%] Meshing curve 34 (Line)
# Info    : [ 40%] Meshing curve 35 (Line)
# Info    : [ 40%] Meshing curve 36 (Line)
# Info    : [ 40%] Meshing curve 37 (Line)
# Info    : [ 40%] Meshing curve 38 (Line)
# Info    : [ 40%] Meshing curve 39 (Line)
# Info    : [ 40%] Meshing curve 40 (Line)
# Info    : [ 40%] Meshing curve 41 (Line)
# Info    : [ 50%] Meshing curve 42 (Line)
# Info    : [ 50%] Meshing curve 43 (Line)
# Info    : [ 50%] Meshing curve 44 (Line)
# Info    : [ 50%] Meshing curve 45 (Line)
# Info    : [ 50%] Meshing curve 46 (Line)
# Info    : [ 50%] Meshing curve 47 (Line)
# Info    : [ 50%] Meshing curve 48 (Line)
# Info    : [ 50%] Meshing curve 49 (Line)
# Info    : [ 50%] Meshing curve 50 (Line)
# Info    : [ 50%] Meshing curve 51 (Line)
# Info    : [ 50%] Meshing curve 52 (Line)
# Info    : [ 60%] Meshing curve 53 (Line)
# Info    : [ 60%] Meshing curve 54 (Line)
# Info    : [ 60%] Meshing curve 55 (Line)
# Info    : [ 60%] Meshing curve 56 (Line)
# Info    : [ 60%] Meshing curve 57 (Line)
# Info    : [ 60%] Meshing curve 58 (Line)
# Info    : [ 60%] Meshing curve 59 (Line)
# Info    : [ 60%] Meshing curve 60 (Line)
# Info    : [ 60%] Meshing curve 61 (Line)
# Info    : [ 60%] Meshing curve 62 (Line)
# Info    : [ 70%] Meshing curve 63 (Line)
# Info    : [ 70%] Meshing curve 64 (Line)
# Info    : [ 70%] Meshing curve 65 (Line)
# Info    : [ 70%] Meshing curve 66 (Line)
# Info    : [ 70%] Meshing curve 67 (Line)
# Info    : [ 70%] Meshing curve 68 (Line)
# Info    : [ 70%] Meshing curve 69 (Line)
# Info    : [ 70%] Meshing curve 70 (Line)
# Info    : [ 70%] Meshing curve 71 (Line)
# Info    : [ 70%] Meshing curve 72 (Line)
# Info    : [ 80%] Meshing curve 73 (Line)
# Info    : [ 80%] Meshing curve 74 (Line)
# Info    : [ 80%] Meshing curve 75 (Line)
# Info    : [ 80%] Meshing curve 76 (Line)
# Info    : [ 80%] Meshing curve 77 (Line)
# Info    : [ 80%] Meshing curve 78 (Line)
# Info    : [ 80%] Meshing curve 79 (Line)
# Info    : [ 80%] Meshing curve 80 (Line)
# Info    : [ 80%] Meshing curve 81 (Line)
# Info    : [ 80%] Meshing curve 82 (Line)
# Info    : [ 90%] Meshing curve 83 (Line)
# Info    : [ 90%] Meshing curve 84 (Line)
# Info    : [ 90%] Meshing curve 85 (Line)
# Info    : [ 90%] Meshing curve 86 (Line)
# Info    : [ 90%] Meshing curve 87 (Line)
# Info    : [ 90%] Meshing curve 88 (Line)
# Info    : [ 90%] Meshing curve 89 (Line)
# Info    : [ 90%] Meshing curve 90 (Line)
# Info    : [ 90%] Meshing curve 91 (Line)
# Info    : [ 90%] Meshing curve 92 (Line)
# Info    : [100%] Meshing curve 93 (Line)
# Info    : [100%] Meshing curve 94 (Line)
# Info    : [100%] Meshing curve 95 (Line)
# Info    : [100%] Meshing curve 96 (Line)
# Info    : [100%] Meshing curve 97 (Line)
# Info    : [100%] Meshing curve 98 (Line)
# Info    : [100%] Meshing curve 99 (Line)
# Info    : [100%] Meshing curve 100 (Line)
# Info    : [100%] Meshing curve 101 (Line)
# Info    : [100%] Meshing curve 102 (Line)
# Info    : Done meshing 1D (Wall 0.0477737s, CPU 0.039192s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0735932s, CPU 0.072806s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 1.7148e-05s, CPU 2.1e-05s)
# Info    : 2642 nodes 4276 elements
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Nurb)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Nurb)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Line)
# Info    : [ 10%] Meshing curve 10 (Line)
# Info    : [ 10%] Meshing curve 11 (Line)
# Info    : [ 20%] Meshing curve 12 (Line)
# Info    : [ 20%] Meshing curve 13 (Line)
# Info    : [ 20%] Meshing curve 14 (Line)
# Info    : [ 20%] Meshing curve 15 (Line)
# Info    : [ 20%] Meshing curve 16 (Line)
# Info    : [ 20%] Meshing curve 17 (Line)
# Info    : [ 20%] Meshing curve 18 (Line)
# Info    : [ 20%] Meshing curve 19 (Line)
# Info    : [ 20%] Meshing curve 20 (Line)
# Info    : [ 20%] Meshing curve 21 (Line)
# Info    : [ 30%] Meshing curve 22 (Line)
# Info    : [ 30%] Meshing curve 23 (Line)
# Info    : [ 30%] Meshing curve 24 (Line)
# Info    : [ 30%] Meshing curve 25 (Line)
# Info    : [ 30%] Meshing curve 26 (Line)
# Info    : [ 30%] Meshing curve 27 (Line)
# Info    : [ 30%] Meshing curve 28 (Line)
# Info    : [ 30%] Meshing curve 29 (Line)
# Info    : [ 30%] Meshing curve 30 (Line)
# Info    : [ 30%] Meshing curve 31 (Line)
# Info    : [ 40%] Meshing curve 32 (Line)
# Info    : [ 40%] Meshing curve 33 (Line)
# Info    : [ 40%] Meshing curve 34 (Line)
# Info    : [ 40%] Meshing curve 35 (Line)
# Info    : [ 40%] Meshing curve 36 (Line)
# Info    : [ 40%] Meshing curve 37 (Line)
# Info    : [ 40%] Meshing curve 38 (Line)
# Info    : [ 40%] Meshing curve 39 (Line)
# Info    : [ 40%] Meshing curve 40 (Line)
# Info    : [ 40%] Meshing curve 41 (Line)
# Info    : [ 50%] Meshing curve 42 (Line)
# Info    : [ 50%] Meshing curve 43 (Line)
# Info    : [ 50%] Meshing curve 44 (Line)
# Info    : [ 50%] Meshing curve 45 (Line)
# Info    : [ 50%] Meshing curve 46 (Line)
# Info    : [ 50%] Meshing curve 47 (Line)
# Info    : [ 50%] Meshing curve 48 (Line)
# Info    : [ 50%] Meshing curve 49 (Line)
# Info    : [ 50%] Meshing curve 50 (Line)
# Info    : [ 50%] Meshing curve 51 (Line)
# Info    : [ 50%] Meshing curve 52 (Line)
# Info    : [ 60%] Meshing curve 53 (Line)
# Info    : [ 60%] Meshing curve 54 (Line)
# Info    : [ 60%] Meshing curve 55 (Line)
# Info    : [ 60%] Meshing curve 56 (Line)
# Info    : [ 60%] Meshing curve 57 (Line)
# Info    : [ 60%] Meshing curve 58 (Line)
# Info    : [ 60%] Meshing curve 59 (Line)
# Info    : [ 60%] Meshing curve 60 (Line)
# Info    : [ 60%] Meshing curve 61 (Line)
# Info    : [ 60%] Meshing curve 62 (Line)
# Info    : [ 70%] Meshing curve 63 (Line)
# Info    : [ 70%] Meshing curve 64 (Line)
# Info    : [ 70%] Meshing curve 65 (Line)
# Info    : [ 70%] Meshing curve 66 (Line)
# Info    : [ 70%] Meshing curve 67 (Line)
# Info    : [ 70%] Meshing curve 68 (Line)
# Info    : [ 70%] Meshing curve 69 (Line)
# Info    : [ 70%] Meshing curve 70 (Line)
# Info    : [ 70%] Meshing curve 71 (Line)
# Info    : [ 70%] Meshing curve 72 (Line)
# Info    : [ 80%] Meshing curve 73 (Line)
# Info    : [ 80%] Meshing curve 74 (Line)
# Info    : [ 80%] Meshing curve 75 (Line)
# Info    : [ 80%] Meshing curve 76 (Line)
# Info    : [ 80%] Meshing curve 77 (Line)
# Info    : [ 80%] Meshing curve 78 (Line)
# Info    : [ 80%] Meshing curve 79 (Line)
# Info    : [ 80%] Meshing curve 80 (Line)
# Info    : [ 80%] Meshing curve 81 (Line)
# Info    : [ 80%] Meshing curve 82 (Line)
# Info    : [ 90%] Meshing curve 83 (Line)
# Info    : [ 90%] Meshing curve 84 (Line)
# Info    : [ 90%] Meshing curve 85 (Line)
# Info    : [ 90%] Meshing curve 86 (Line)
# Info    : [ 90%] Meshing curve 87 (Line)
# Info    : [ 90%] Meshing curve 88 (Line)
# Info    : [ 90%] Meshing curve 89 (Line)
# Info    : [ 90%] Meshing curve 90 (Line)
# Info    : [ 90%] Meshing curve 91 (Line)
# Info    : [ 90%] Meshing curve 92 (Line)
# Info    : [100%] Meshing curve 93 (Line)
# Info    : [100%] Meshing curve 94 (Line)
# Info    : [100%] Meshing curve 95 (Line)
# Info    : [100%] Meshing curve 96 (Line)
# Info    : [100%] Meshing curve 97 (Line)
# Info    : [100%] Meshing curve 98 (Line)
# Info    : [100%] Meshing curve 99 (Line)
# Info    : [100%] Meshing curve 100 (Line)
# Info    : [100%] Meshing curve 101 (Line)
# Info    : [100%] Meshing curve 102 (Line)
# Info    : Done meshing 1D (Wall 0.0482091s, CPU 0.049414s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0974866s, CPU 0.08703s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 1.3197e-05s, CPU 1.4e-05s)
# Info    : 2680 nodes 4338 elements
# 2023-04-27 06:04:12,650	WARNING services.py:1780 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67035136 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=1.56gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2023-04-27 06:04:13,859	INFO worker.py:1544 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (execute_su2 pid=24401) WARNING: The current SST-1994m model is inconsistent with literature. We recommend using the SST-2003m model.
# (execute_su2 pid=24401) In SU2 v8 the 2003m model will become default, and the inconsistency will be fixed.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) Parsing config file for zone 0
# (execute_su2 pid=24401) WARNING: The current SST-1994m model is inconsistent with literature. We recommend using the SST-2003m model.
# (execute_su2 pid=24401) In SU2 v8 the 2003m model will become default, and the inconsistency will be fixed.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ----------------- Physical Case Definition ( Zone 0 ) -------------------
# (execute_su2 pid=24401) Compressible RANS equations.
# (execute_su2 pid=24401) Turbulence model: Menter's k-omega SST-1994m with no production modification.
# (execute_su2 pid=24401) Hybrid RANS/LES: No Hybrid RANS/LES
# (execute_su2 pid=24401) Mach number: 0.396501.
# (execute_su2 pid=24401) Angle of attack (AoA): 0 deg, and angle of sideslip (AoS): 0 deg.
# (execute_su2 pid=24401) Reynolds number: 0. Reference length 1.
# (execute_su2 pid=24401) No restart solution, use the values at infinity (freestream).
# (execute_su2 pid=24401) Dimensional simulation.
# (execute_su2 pid=24401) The reference area is 1 m^2.
# (execute_su2 pid=24401) The semi-span will be computed using the max y(3D) value.
# (execute_su2 pid=24401) The reference length is 1 m.
# (execute_su2 pid=24401) Surface(s) plotted in the output file: wall1, wall2.
# (execute_su2 pid=24401) Surface(s) to be analyzed in detail: outflow.
# (execute_su2 pid=24401) Input mesh file name: /workspaces/parafoil/simulation/passage1.su2
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) --------------- Space Numerical Integration ( Zone 0 ) ------------------
# (execute_su2 pid=24401) Roe (with entropy fix = 0.1) solver for the flow inviscid terms.
# (execute_su2 pid=24401) Standard Roe without low-dissipation function.
# (execute_su2 pid=24401) Second order integration in space, with slope limiter.
# (execute_su2 pid=24401) Van Albada slope-limiting method implemented by edges.
# (execute_su2 pid=24401) Scalar upwind solver for the turbulence model.
# (execute_su2 pid=24401) First order integration in space.
# (execute_su2 pid=24401) Average of gradients with correction (viscous flow terms).
# (execute_su2 pid=24401) Average of gradients with correction (viscous turbulence terms).
# (execute_su2 pid=24401) Gradient for upwind reconstruction: inverse-distance weighted Least-Squares.
# (execute_su2 pid=24401) Gradient for viscous and source terms: inverse-distance weighted Least-Squares.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) --------------- Time Numerical Integration  ( Zone 0 ) ------------------
# (execute_su2 pid=24401) Local time stepping (steady state simulation).
# (execute_su2 pid=24401) Euler implicit method for the flow equations.
# (execute_su2 pid=24401) FGMRES is used for solving the linear system.
# (execute_su2 pid=24401) Using a LU-SGS preconditioning.
# (execute_su2 pid=24401) Convergence criteria of the linear solver: 1e-06.
# (execute_su2 pid=24401) Max number of linear iterations: 10.
# (execute_su2 pid=24401) No CFL adaptation.
# (execute_su2 pid=24401) Courant-Friedrichs-Lewy number:       10
# (execute_su2 pid=24401) Euler implicit time integration for the turbulence model.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------ Convergence Criteria  ( Zone 0 ) ---------------------
# (execute_su2 pid=24401) Maximum number of solver subiterations: 1.
# (execute_su2 pid=24401) Maximum number of solver outer iterations: 21.
# (execute_su2 pid=24401) Begin convergence monitoring at iteration 10.
# (execute_su2 pid=24401) Residual minimum value: 1e-16.
# (execute_su2 pid=24401) Cauchy series min. value: 1e-06.
# (execute_su2 pid=24401) Number of Cauchy elements: 100.
# (execute_su2 pid=24401) Begin windowed time average at iteration 0.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) -------------------- Output Information ( Zone 0 ) ----------------------
# (execute_su2 pid=24401) File writing frequency:
# (execute_su2 pid=24401) +------------------------------------+
# (execute_su2 pid=24401) |                     File| Frequency|
# (execute_su2 pid=24401) +------------------------------------+
# (execute_su2 pid=24401) |                  RESTART|      1000|
# (execute_su2 pid=24401) |                 PARAVIEW|      1000|
# (execute_su2 pid=24401) |         SURFACE_PARAVIEW|      1000|
# (execute_su2 pid=24401) +------------------------------------+
# (execute_su2 pid=24401) Writing the convergence history file every 1 inner iterations.
# (execute_su2 pid=24401) Writing the convergence history file every 1 outer iterations.
# (execute_su2 pid=24401) Writing the screen convergence history every 1 inner iterations.
# (execute_su2 pid=24401) Writing the screen convergence history every 1 outer iterations.
# (execute_su2 pid=24401) The tabular file format is CSV (.csv).
# (execute_su2 pid=24401) Convergence history file name: /workspaces/parafoil/simulation/history1.
# (execute_su2 pid=24401) Forces breakdown file name: forces_breakdown.dat.
# (execute_su2 pid=24401) Surface file name: /workspaces/parafoil/simulation/surface_flow1.
# (execute_su2 pid=24401) Volume file name: /workspaces/parafoil/simulation/flow1.
# (execute_su2 pid=24401) Restart file name: /workspaces/parafoil/simulation/restart_flow1.dat.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------- Config File Boundary Information ( Zone 0 ) ---------------
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401) |                        Marker Type|                        Marker Name|
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401) |                  Periodic boundary|                          periodic1|
# (execute_su2 pid=24401) |                                   |                          periodic3|
# (execute_su2 pid=24401) |                                   |                          periodic2|
# (execute_su2 pid=24401) |                                   |                          periodic4|
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401) |                     Giles boundary|                             inflow|
# (execute_su2 pid=24401) |                                   |                             outmix|
# (execute_su2 pid=24401) |                                   |                              inmix|
# (execute_su2 pid=24401) |                                   |                            outflow|
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401) |               MixingPlane boundary|                             outmix|
# (execute_su2 pid=24401) |                                   |                              inmix|
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401) |                     Heat flux wall|                              wall1|
# (execute_su2 pid=24401) |                                   |                              wall2|
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) Parsing config file for zone 1
# (execute_su2 pid=24401) WARNING: The current SST-1994m model is inconsistent with literature. We recommend using the SST-2003m model.
# (execute_su2 pid=24401) In SU2 v8 the 2003m model will become default, and the inconsistency will be fixed.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ----------------- Physical Case Definition ( Zone 1 ) -------------------
# (execute_su2 pid=24401) Compressible RANS equations.
# (execute_su2 pid=24401) Turbulence model: Menter's k-omega SST-1994m with no production modification.
# (execute_su2 pid=24401) Hybrid RANS/LES: No Hybrid RANS/LES
# (execute_su2 pid=24401) Mach number: 0.396501.
# (execute_su2 pid=24401) Angle of attack (AoA): 0 deg, and angle of sideslip (AoS): 0 deg.
# (execute_su2 pid=24401) Reynolds number: 0. Reference length 1.
# (execute_su2 pid=24401) No restart solution, use the values at infinity (freestream).
# (execute_su2 pid=24401) Dimensional simulation.
# (execute_su2 pid=24401) The reference area is 1 m^2.
# (execute_su2 pid=24401) The semi-span will be computed using the max y(3D) value.
# (execute_su2 pid=24401) The reference length is 1 m.
# (execute_su2 pid=24401) Surface(s) plotted in the output file: wall1, wall2.
# (execute_su2 pid=24401) Surface(s) to be analyzed in detail: outflow.
# (execute_su2 pid=24401) Input mesh file name: /workspaces/parafoil/simulation/passage1.su2
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) --------------- Space Numerical Integration ( Zone 1 ) ------------------
# (execute_su2 pid=24401) Roe (with entropy fix = 0.1) solver for the flow inviscid terms.
# (execute_su2 pid=24401) Standard Roe without low-dissipation function.
# (execute_su2 pid=24401) Second order integration in space, with slope limiter.
# (execute_su2 pid=24401) Van Albada slope-limiting method implemented by edges.
# (execute_su2 pid=24401) Scalar upwind solver for the turbulence model.
# (execute_su2 pid=24401) First order integration in space.
# (execute_su2 pid=24401) Average of gradients with correction (viscous flow terms).
# (execute_su2 pid=24401) Average of gradients with correction (viscous turbulence terms).
# (execute_su2 pid=24401) Gradient for upwind reconstruction: inverse-distance weighted Least-Squares.
# (execute_su2 pid=24401) Gradient for viscous and source terms: inverse-distance weighted Least-Squares.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) --------------- Time Numerical Integration  ( Zone 1 ) ------------------
# (execute_su2 pid=24401) Local time stepping (steady state simulation).
# (execute_su2 pid=24401) Euler implicit method for the flow equations.
# (execute_su2 pid=24401) FGMRES is used for solving the linear system.
# (execute_su2 pid=24401) Using a LU-SGS preconditioning.
# (execute_su2 pid=24401) Convergence criteria of the linear solver: 1e-06.
# (execute_su2 pid=24401) Max number of linear iterations: 10.
# (execute_su2 pid=24401) No CFL adaptation.
# (execute_su2 pid=24401) Courant-Friedrichs-Lewy number:       10
# (execute_su2 pid=24401) Euler implicit time integration for the turbulence model.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------ Convergence Criteria  ( Zone 1 ) ---------------------
# (execute_su2 pid=24401) Maximum number of solver subiterations: 1.
# (execute_su2 pid=24401) Maximum number of solver outer iterations: 21.
# (execute_su2 pid=24401) Begin convergence monitoring at iteration 10.
# (execute_su2 pid=24401) Residual minimum value: 1e-16.
# (execute_su2 pid=24401) Cauchy series min. value: 1e-06.
# (execute_su2 pid=24401) Number of Cauchy elements: 100.
# (execute_su2 pid=24401) Begin windowed time average at iteration 0.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) -------------------- Output Information ( Zone 1 ) ----------------------
# (execute_su2 pid=24401) File writing frequency:
# (execute_su2 pid=24401) +------------------------------------+
# (execute_su2 pid=24401) |                     File| Frequency|
# (execute_su2 pid=24401) +------------------------------------+
# (execute_su2 pid=24401) |                  RESTART|      1000|
# (execute_su2 pid=24401) |                 PARAVIEW|      1000|
# (execute_su2 pid=24401) |         SURFACE_PARAVIEW|      1000|
# (execute_su2 pid=24401) +------------------------------------+
# (execute_su2 pid=24401) Writing the convergence history file every 1 inner iterations.
# (execute_su2 pid=24401) Writing the convergence history file every 1 outer iterations.
# (execute_su2 pid=24401) Writing the screen convergence history every 1 inner iterations.
# (execute_su2 pid=24401) Writing the screen convergence history every 1 outer iterations.
# (execute_su2 pid=24401) The tabular file format is CSV (.csv).
# (execute_su2 pid=24401) Convergence history file name: /workspaces/parafoil/simulation/history1.
# (execute_su2 pid=24401) Forces breakdown file name: forces_breakdown.dat.
# (execute_su2 pid=24401) Surface file name: /workspaces/parafoil/simulation/surface_flow1.
# (execute_su2 pid=24401) Volume file name: /workspaces/parafoil/simulation/flow1.
# (execute_su2 pid=24401) Restart file name: /workspaces/parafoil/simulation/restart_flow1.dat.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------- Config File Boundary Information ( Zone 1 ) ---------------
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401) |                        Marker Type|                        Marker Name|
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401) |                  Periodic boundary|                          periodic1|
# (execute_su2 pid=24401) |                                   |                          periodic3|
# (execute_su2 pid=24401) |                                   |                          periodic2|
# (execute_su2 pid=24401) |                                   |                          periodic4|
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401) |                     Giles boundary|                             inflow|
# (execute_su2 pid=24401) |                                   |                             outmix|
# (execute_su2 pid=24401) |                                   |                              inmix|
# (execute_su2 pid=24401) |                                   |                            outflow|
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401) |               MixingPlane boundary|                             outmix|
# (execute_su2 pid=24401) |                                   |                              inmix|
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401) |                     Heat flux wall|                              wall1|
# (execute_su2 pid=24401) |                                   |                              wall2|
# (execute_su2 pid=24401) +-----------------------------------------------------------------------+
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) -------------------- Output Preprocessing ( Zone 0 ) --------------------
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) WARNING: SURFACE_PRESSURE_DROP can only be computed for at least 2 surfaces (outlet, inlet, ...)
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) Screen output fields: OUTER_ITER, INNER_ITER, RMS_DENSITY, RMS_MOMENTUM-X, RMS_MOMENTUM-Y, RMS_ENERGY
# (execute_su2 pid=24401) History output group(s): ITER, RMS_RES
# (execute_su2 pid=24401) Convergence field(s): RMS_DENSITY
# (execute_su2 pid=24401) Warning: No (valid) fields chosen for time convergence monitoring. Time convergence monitoring inactive.
# (execute_su2 pid=24401) Volume output fields: COORDINATES, SOLUTION, PRIMITIVE
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) -------------------- Output Preprocessing ( Zone 1 ) --------------------
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) WARNING: SURFACE_PRESSURE_DROP can only be computed for at least 2 surfaces (outlet, inlet, ...)
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) Screen output fields: OUTER_ITER, INNER_ITER, RMS_DENSITY, RMS_MOMENTUM-X, RMS_MOMENTUM-Y, RMS_ENERGY
# (execute_su2 pid=24401) History output group(s): ITER, RMS_RES
# (execute_su2 pid=24401) Convergence field(s): RMS_DENSITY
# (execute_su2 pid=24401) Warning: No (valid) fields chosen for time convergence monitoring. Time convergence monitoring inactive.
# (execute_su2 pid=24401) Volume output fields: COORDINATES, SOLUTION, PRIMITIVE
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------- Output Preprocessing ( Multizone ) ------------------
# (execute_su2 pid=24401) Screen output fields: OUTER_ITER, AVG_BGS_RES[0], AVG_BGS_RES[1], RMS_DENSITY[0], RMS_ENERGY[0], RMS_DENSITY[1], RMS_ENERGY[1], SURFACE_TOTAL_PRESSURE[1]
# (execute_su2 pid=24401)   Info: Ignoring the following history output groups:
# (execute_su2 pid=24401)   AVG_RES[0], AVG_RES[1]
# (execute_su2 pid=24401) History output group(s): ITER, BGS_RES[0], BGS_RES[1]
# (execute_su2 pid=24401) Convergence field(s): AVG_BGS_RES[0]
# (execute_su2 pid=24401) Warning: No (valid) fields chosen for time convergence monitoring. Time convergence monitoring inactive.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------- Geometry Preprocessing ( Zone 0 ) -------------------
# (execute_su2 pid=24401) Reading zone 0 from native SU2 ASCII mesh.
# (execute_su2 pid=24401) Two dimensional problem.
# (execute_su2 pid=24401) 2624 grid points.
# (execute_su2 pid=24401) 3900 volume elements.
# (execute_su2 pid=24401) 5 surface markers.
# (execute_su2 pid=24401) 30 boundary elements in index 0 (Marker = periodic2).
# (execute_su2 pid=24401) 20 boundary elements in index 1 (Marker = outmix).
# (execute_su2 pid=24401) 30 boundary elements in index 2 (Marker = periodic1).
# (execute_su2 pid=24401) 20 boundary elements in index 3 (Marker = inflow).
# (execute_su2 pid=24401) 156 boundary elements in index 4 (Marker = wall1).
# (execute_su2 pid=24401) 2808 triangles.
# (execute_su2 pid=24401) 1092 quadrilaterals.
# (execute_su2 pid=24401) Setting point connectivity.
# (execute_su2 pid=24401) Renumbering points (Reverse Cuthill McKee Ordering).
# (execute_su2 pid=24401) Recomputing point connectivity.
# (execute_su2 pid=24401) Setting element connectivity.
# (execute_su2 pid=24401) Checking the numerical grid orientation.
# (execute_su2 pid=24401) There has been a re-orientation of 2808 TRIANGLE volume elements.
# (execute_su2 pid=24401) There has been a re-orientation of 1092 QUADRILATERAL volume elements.
# (execute_su2 pid=24401) There has been a re-orientation of 100 LINE surface elements.
# (execute_su2 pid=24401) Identifying edges and vertices.
# (execute_su2 pid=24401) Setting the control volume structure.
# (execute_su2 pid=24401) Area of the computational grid: 0.00349352.
# (execute_su2 pid=24401) Searching for the closest normal neighbors to the surfaces.
# (execute_su2 pid=24401) Storing a mapping from global to local point index.
# (execute_su2 pid=24401) Compute the surface curvature.
# (execute_su2 pid=24401) Max K: 20606.4. Mean K: 322.556. Standard deviation K: 2026.88.
# (execute_su2 pid=24401) Checking for periodicity.
# (execute_su2 pid=24401) Computing mesh quality statistics for the dual control volumes.
# (execute_su2 pid=24401) +--------------------------------------------------------------+
# (execute_su2 pid=24401) |           Mesh Quality Metric|        Minimum|        Maximum|
# (execute_su2 pid=24401) +--------------------------------------------------------------+
# (execute_su2 pid=24401) |    Orthogonality Angle (deg.)|        60.9735|        89.9265|
# (execute_su2 pid=24401) |     CV Face Area Aspect Ratio|        1.00244|        39.4712|
# (execute_su2 pid=24401) |           CV Sub-Volume Ratio|        1.00009|         8.6301|
# (execute_su2 pid=24401) +--------------------------------------------------------------+
# (execute_su2 pid=24401) Finding max control volume width.
# (execute_su2 pid=24401) Wetted area = 0 m.
# (execute_su2 pid=24401) Area projection in the x-plane = 0 m, y-plane = 0 m.
# (execute_su2 pid=24401) Max. coordinate in the x-direction = -1e+10 m, y-direction = -1e+10 m.
# (execute_su2 pid=24401) Min. coordinate in the x-direction = 1e+10 m, y-direction = 1e+10 m.
# (execute_su2 pid=24401) Matching the periodic boundary points for marker pair 1.
# (execute_su2 pid=24401)  Matched 62 points with a max distance of: 2.1693e-10.
# (execute_su2 pid=24401) Matching the periodic boundary points for marker pair 2.
# (execute_su2 pid=24401)  No matching points for periodic marker pair 2 in current zone.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------- Geometry Preprocessing ( Zone 1 ) -------------------
# (execute_su2 pid=24401) Reading zone 1 from native SU2 ASCII mesh.
# (execute_su2 pid=24401) Two dimensional problem.
# (execute_su2 pid=24401) 2662 grid points.
# (execute_su2 pid=24401) 3960 volume elements.
# (execute_su2 pid=24401) 5 surface markers.
# (execute_su2 pid=24401) 30 boundary elements in index 0 (Marker = periodic4).
# (execute_su2 pid=24401) 20 boundary elements in index 1 (Marker = outflow).
# (execute_su2 pid=24401) 30 boundary elements in index 2 (Marker = periodic3).
# (execute_su2 pid=24401) 20 boundary elements in index 3 (Marker = inmix).
# (execute_su2 pid=24401) 158 boundary elements in index 4 (Marker = wall2).
# (execute_su2 pid=24401) 2854 triangles.
# (execute_su2 pid=24401) 1106 quadrilaterals.
# (execute_su2 pid=24401) Setting point connectivity.
# (execute_su2 pid=24401) Renumbering points (Reverse Cuthill McKee Ordering).
# (execute_su2 pid=24401) Recomputing point connectivity.
# (execute_su2 pid=24401) Setting element connectivity.
# (execute_su2 pid=24401) Checking the numerical grid orientation.
# (execute_su2 pid=24401) There has been a re-orientation of 2854 TRIANGLE volume elements.
# (execute_su2 pid=24401) There has been a re-orientation of 1106 QUADRILATERAL volume elements.
# (execute_su2 pid=24401) There has been a re-orientation of 100 LINE surface elements.
# (execute_su2 pid=24401) Identifying edges and vertices.
# (execute_su2 pid=24401) Setting the control volume structure.
# (execute_su2 pid=24401) Area of the computational grid: 0.00349046.
# (execute_su2 pid=24401) Searching for the closest normal neighbors to the surfaces.
# (execute_su2 pid=24401) Storing a mapping from global to local point index.
# (execute_su2 pid=24401) Compute the surface curvature.
# (execute_su2 pid=24401) Max K: 21031.9. Mean K: 320.381. Standard deviation K: 2033.08.
# (execute_su2 pid=24401) Checking for periodicity.
# (execute_su2 pid=24401) Computing mesh quality statistics for the dual control volumes.
# (execute_su2 pid=24401) +--------------------------------------------------------------+
# (execute_su2 pid=24401) |           Mesh Quality Metric|        Minimum|        Maximum|
# (execute_su2 pid=24401) +--------------------------------------------------------------+
# (execute_su2 pid=24401) |    Orthogonality Angle (deg.)|        72.1159|        89.7808|
# (execute_su2 pid=24401) |     CV Face Area Aspect Ratio|        1.00209|        38.8177|
# (execute_su2 pid=24401) |           CV Sub-Volume Ratio|        1.00006|        8.66417|
# (execute_su2 pid=24401) +--------------------------------------------------------------+
# (execute_su2 pid=24401) Finding max control volume width.
# (execute_su2 pid=24401) Wetted area = 0 m.
# (execute_su2 pid=24401) Area projection in the x-plane = 0 m, y-plane = 0 m.
# (execute_su2 pid=24401) Max. coordinate in the x-direction = -1e+10 m, y-direction = -1e+10 m.
# (execute_su2 pid=24401) Min. coordinate in the x-direction = 1e+10 m, y-direction = 1e+10 m.
# (execute_su2 pid=24401) Matching the periodic boundary points for marker pair 1.
# (execute_su2 pid=24401)  No matching points for periodic marker pair 1 in current zone.
# (execute_su2 pid=24401) Matching the periodic boundary points for marker pair 2.
# (execute_su2 pid=24401)  Matched 62 points with a max distance of: 2.19591e-10.
# (execute_su2 pid=24401) Computing wall distances.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) -------------------- Solver Preprocessing ( Zone 0 ) --------------------
# (execute_su2 pid=24401) Viscous flow: Computing pressure using the ideal gas law
# (execute_su2 pid=24401) based on the free-stream temperature and a density computed
# (execute_su2 pid=24401) from the Reynolds number.
# (execute_su2 pid=24401) Force coefficients computed using free-stream values.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) -- Models:
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |          Viscosity Model|        Conductivity Model|              Fluid Model|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |               SUTHERLAND|          CONSTANT_PRANDTL|                IDEAL_GAS|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) -- Fluid properties:
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |                  Name|    Dim. value|    Ref. value|      Unit|Non-dim. value|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |        Ref. Viscosity|     1.716e-05|             1|   N.s/m^2|     1.716e-05|
# (execute_su2 pid=24401) |      Sutherland Temp.|        273.15|             1|         K|        273.15|
# (execute_su2 pid=24401) |     Sutherland Const.|         110.4|             1|         K|         110.4|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |        Prandtl (Lam.)|             -|             -|         -|          0.72|
# (execute_su2 pid=24401) |       Prandtl (Turb.)|             -|             -|         -|           0.9|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |          Gas Constant|       287.115|             1|  N.m/kg.K|       287.115|
# (execute_su2 pid=24401) |      Spec. Heat Ratio|             -|             -|         -|       1.40216|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) -- Initial and free-stream conditions:
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |                  Name|    Dim. value|    Ref. value|      Unit|Non-dim. value|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |       Static Pressure|        101000|             1|        Pa|        101000|
# (execute_su2 pid=24401) |               Density|       1.22144|             1|    kg/m^3|       1.22144|
# (execute_su2 pid=24401) |           Temperature|           288|             1|         K|           288|
# (execute_su2 pid=24401) |          Total Energy|        214793|             1|   m^2/s^2|        214793|
# (execute_su2 pid=24401) |            Velocity-X|       135.011|             1|       m/s|       135.011|
# (execute_su2 pid=24401) |            Velocity-Y|             0|             1|       m/s|             0|
# (execute_su2 pid=24401) |    Velocity Magnitude|       135.011|             1|       m/s|       135.011|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |             Viscosity|   1.78857e-05|             1|   N.s/m^2|   1.78857e-05|
# (execute_su2 pid=24401) |          Conductivity|             -|             1|   W/m^2.K|             -|
# (execute_su2 pid=24401) |     Turb. Kin. Energy|       68.3546|             1|   m^2/s^2|       68.3546|
# (execute_su2 pid=24401) |     Spec. Dissipation|        466803|             1|       1/s|        466803|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |           Mach Number|             -|             -|         -|      0.396501|
# (execute_su2 pid=24401) |       Reynolds Number|             -|             -|         -|   9.22006e+06|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) Initialize Jacobian structure (Navier-Stokes). MG level: 0.
# (execute_su2 pid=24401) Initialize Jacobian structure (SST model).
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------- Numerics Preprocessing ( Zone 0 ) -------------------
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ----------------- Integration Preprocessing ( Zone 0 ) ------------------
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------- Iteration Preprocessing ( Zone 0 ) ------------------
# (execute_su2 pid=24401) Euler/Navier-Stokes/RANS turbomachinery fluid iteration.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) -------------------- Solver Preprocessing ( Zone 1 ) --------------------
# (execute_su2 pid=24401) Viscous flow: Computing pressure using the ideal gas law
# (execute_su2 pid=24401) based on the free-stream temperature and a density computed
# (execute_su2 pid=24401) from the Reynolds number.
# (execute_su2 pid=24401) Force coefficients computed using free-stream values.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) -- Models:
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |          Viscosity Model|        Conductivity Model|              Fluid Model|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |               SUTHERLAND|          CONSTANT_PRANDTL|                IDEAL_GAS|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) -- Fluid properties:
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |                  Name|    Dim. value|    Ref. value|      Unit|Non-dim. value|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |        Ref. Viscosity|     1.716e-05|             1|   N.s/m^2|     1.716e-05|
# (execute_su2 pid=24401) |      Sutherland Temp.|        273.15|             1|         K|        273.15|
# (execute_su2 pid=24401) |     Sutherland Const.|         110.4|             1|         K|         110.4|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |        Prandtl (Lam.)|             -|             -|         -|          0.72|
# (execute_su2 pid=24401) |       Prandtl (Turb.)|             -|             -|         -|           0.9|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |          Gas Constant|       287.115|             1|  N.m/kg.K|       287.115|
# (execute_su2 pid=24401) |      Spec. Heat Ratio|             -|             -|         -|       1.40216|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) -- Initial and free-stream conditions:
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |                  Name|    Dim. value|    Ref. value|      Unit|Non-dim. value|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |       Static Pressure|        101000|             1|        Pa|        101000|
# (execute_su2 pid=24401) |               Density|       1.22144|             1|    kg/m^3|       1.22144|
# (execute_su2 pid=24401) |           Temperature|           288|             1|         K|           288|
# (execute_su2 pid=24401) |          Total Energy|        214793|             1|   m^2/s^2|        214793|
# (execute_su2 pid=24401) |            Velocity-X|       135.011|             1|       m/s|       135.011|
# (execute_su2 pid=24401) |            Velocity-Y|             0|             1|       m/s|             0|
# (execute_su2 pid=24401) |    Velocity Magnitude|       135.011|             1|       m/s|       135.011|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |             Viscosity|   1.78857e-05|             1|   N.s/m^2|   1.78857e-05|
# (execute_su2 pid=24401) |          Conductivity|             -|             1|   W/m^2.K|             -|
# (execute_su2 pid=24401) |     Turb. Kin. Energy|       68.3546|             1|   m^2/s^2|       68.3546|
# (execute_su2 pid=24401) |     Spec. Dissipation|        466803|             1|       1/s|        466803|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) |           Mach Number|             -|             -|         -|      0.396501|
# (execute_su2 pid=24401) |       Reynolds Number|             -|             -|         -|   9.22006e+06|
# (execute_su2 pid=24401) +------------------------------------------------------------------------------+
# (execute_su2 pid=24401) Initialize Jacobian structure (Navier-Stokes). MG level: 0.
# (execute_su2 pid=24401) Initialize Jacobian structure (SST model).
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------- Numerics Preprocessing ( Zone 1 ) -------------------
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ----------------- Integration Preprocessing ( Zone 1 ) ------------------
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------- Iteration Preprocessing ( Zone 1 ) ------------------
# (execute_su2 pid=24401) Euler/Navier-Stokes/RANS turbomachinery fluid iteration.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------- Multizone Interface Preprocessing -------------------
# (execute_su2 pid=24401) Set mixing-plane interface from donor zone 1 to target zone 0.
# (execute_su2 pid=24401) Set mixing-plane interface from donor zone 0 to target zone 1.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ---------------------- Turbomachinery Preprocessing ---------------------
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) Initialize Turbo Vertex Structure.
# (execute_su2 pid=24401) Number of span-wise sections in Zone 0: 1.
# (execute_su2 pid=24401) TURBOMACHINERY folder creation failed.
# (execute_su2 pid=24401) Number of span-wise sections in Zone 1: 1.
# (execute_su2 pid=24401) Max number of span-wise sections among all zones: 1.
# (execute_su2 pid=24401) Initialize solver containers for average and performance quantities.
# (execute_su2 pid=24401) Compute inflow and outflow average geometric quantities.
# (execute_su2 pid=24401) Set span-wise sections between zones on Mixing-Plane interface.
# (execute_su2 pid=24401) Transfer average geometric quantities to zone 0.
# (execute_su2 pid=24401) Inlet area for Row 1: 577 cm^2.
# (execute_su2 pid=24401) Oulet area for Row 1: 577 cm^2.
# (execute_su2 pid=24401) Recomputed number of blades for Row 1: 17.331.
# (execute_su2 pid=24401) Inlet area for Row 2: 577 cm^2.
# (execute_su2 pid=24401) Oulet area for Row 2: 577 cm^2.
# (execute_su2 pid=24401) Recomputed number of blades for Row 2: 17.331.
# (execute_su2 pid=24401) Preprocessing of the Mixing-Plane Interface.
# (execute_su2 pid=24401) Initialize turbomachinery solution quantities.
# (execute_su2 pid=24401) Initialize inflow and outflow average solution quantities.
# (execute_su2 pid=24401) Inlet flow angle for Row 1: 0°.
# (execute_su2 pid=24401) Outlet flow angle for Row 1: 0°.
# (execute_su2 pid=24401) Inlet flow angle for Row 2: 0°.
# (execute_su2 pid=24401) Outlet flow angle for Row 2: 0°.
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) --------------------------- Finalizing Solver ---------------------------
# (execute_su2 pid=24401) Deleted CNumerics container.
# (execute_su2 pid=24401) Deleted CIntegration container.
# (execute_su2 pid=24401) Deleted CSolver container.
# (execute_su2 pid=24401) Deleted CIteration container.
# (execute_su2 pid=24401) Deleted CInterface container.
# (execute_su2 pid=24401) Deleted CGeometry container.
# (execute_su2 pid=24401) Deleted CFreeFormDefBox class.
# (execute_su2 pid=24401) Deleted CSurfaceMovement class.
# (execute_su2 pid=24401) Deleted CVolumetricMovement class.
# (execute_su2 pid=24401) Deleted CConfig container.
# (execute_su2 pid=24401) Deleted nInst container.
# (execute_su2 pid=24401) Deleted COutput class.
# (execute_su2 pid=24401) -------------------------------------------------------------------------
# (execute_su2 pid=24401)
# (execute_su2 pid=24401) ------------------------- Exit Success (SU2_CFD) ------------------------
# (execute_su2 pid=24401)
